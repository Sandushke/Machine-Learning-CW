# %%
#import the libraries
import re
import seaborn as sns
import numpy.random as rnd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#Load the dataset
with open('Dataset/spambase.names') as spam:
 text = spam.read()
label = re.findall(r'\n(\w*_?\W?):', text)
spamData = pd.read_csv('Dataset/spambase.data', names=label + ['spam'])

# %%
#Read data in the dataset
spamData.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# 1             0.00            0.94  ...         0.00        0.132
# 2             0.64            0.25  ...         0.01        0.143
# 3             0.31            0.63  ...         0.00        0.137
# 4             0.31            0.63  ...         0.00        0.135
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.778        0.000        0.000
# 1          0.0        0.372        0.180        0.048
# 2          0.0        0.276        0.184        0.010
# 3          0.0        0.137        0.000        0.000
# 4          0.0        0.135        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total  spam
# 0                       278     1
# 1                      1028     1
# 2                      2259     1
# 3                       191     1
# 4                       191     1
#
# [5 rows x 58 columns]

# %%
#Plot the feature corelation graph
plt.figure(figsize=(8,6))
sns.heatmap(spamData.corr(), cmap='PuBuGn')
plt.title('Feature Correlation', color='r')
plt.show()

# %%
#Check for null values
spamData.isnull().sum()
# Out:
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_freq_our                 0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# word_freq_lab                 0
# word_freq_labs                0
# word_freq_telnet              0
# word_freq_857                 0
# word_freq_data                0
# word_freq_415                 0
# word_freq_85                  0
# word_freq_technology          0
# word_freq_1999                0
# word_freq_parts               0
# word_freq_pm                  0
# word_freq_direct              0
# word_freq_cs                  0
# word_freq_meeting             0
# word_freq_original            0
# word_freq_project             0
# word_freq_re                  0
# word_freq_edu                 0
# word_freq_table               0
# word_freq_conference          0
# char_freq_;                   0
# char_freq_(                   0
# char_freq_[                   0
# char_freq_!                   0
# char_freq_$                   0
# char_freq_#                   0
# capital_run_length_average    0
# capital_run_length_longest    0
# capital_run_length_total      0
# spam                          0
# dtype: int64

# %%
spamData.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# min         0.000000        0.000000          0.000000            0.000000
# 25%         0.000000        0.000000          0.000000            0.000000
# 50%         0.000000        0.000000          0.000000            0.000000
# 75%         0.380000        0.000000          0.000000            0.000000
# max        10.000000        5.880000          7.270000           11.110000
#
#        word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# count      4601.000000     4601.000000  ...  4601.000000  4601.000000
# mean          0.090067        0.239413  ...     0.038575     0.139030
# std           0.278616        0.644755  ...     0.243471     0.270355
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     0.000000     0.000000
# 50%           0.000000        0.000000  ...     0.000000     0.065000
# 75%           0.000000        0.160000  ...     0.000000     0.188000
# max           5.260000       18.180000  ...     4.385000     9.752000
#
#        char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# count  4601.000000  4601.000000  4601.000000  4601.000000
# mean      0.016976     0.269071     0.075811     0.044238
# std       0.109394     0.815672     0.245882     0.429342
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.315000     0.052000     0.000000
# max       4.081000    32.478000     6.003000    19.829000
#
#        capital_run_length_average  capital_run_length_longest  \
# count                 4601.000000                 4601.000000
# mean                     5.191515                   52.172789
# std                     31.729449                  194.891310
# min                      1.000000                    1.000000
# 25%                      1.588000                    6.000000
# 50%                      2.276000                   15.000000
# 75%                      3.706000                   43.000000
# max                   1102.500000                 9989.000000
#
#        capital_run_length_total         spam
# count               4601.000000  4601.000000
# mean                 283.289285     0.394045
# std                  606.347851     0.488698
# min                    1.000000     0.000000
# 25%                   35.000000     0.000000
# 50%                   95.000000     0.000000
# 75%                  266.000000     1.000000
# max                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %%
#Remove columns with 0 values in all rows
spamData = spamData.drop(labels=['word_freq_3d','char_freq_['], axis=1)
spamData
#Removed 2 columns
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_our  \
# 0               0.00               0.64           0.64           0.32
# 1               0.21               0.28           0.50           0.14
# 2               0.06               0.00           0.71           1.23
# 3               0.00               0.00           0.00           0.63
# 4               0.00               0.00           0.00           0.63
# ...              ...                ...            ...            ...
# 4596            0.31               0.00           0.62           0.00
# 4597            0.00               0.00           0.00           0.00
# 4598            0.30               0.00           0.30           0.00
# 4599            0.96               0.00           0.00           0.32
# 4600            0.00               0.00           0.65           0.00
#
#       word_freq_over  word_freq_remove  word_freq_internet  word_freq_order  \
# 0               0.00              0.00                0.00             0.00
# 1               0.28              0.21                0.07             0.00
# 2               0.19              0.19                0.12             0.64
# 3               0.00              0.31                0.63             0.31
# 4               0.00              0.31                0.63             0.31
# ...              ...               ...                 ...              ...
# 4596            0.31              0.00                0.00             0.00
# 4597            0.00              0.00                0.00             0.00
# 4598            0.00              0.00                0.00             0.00
# 4599            0.00              0.00                0.00             0.00
# 4600            0.00              0.00                0.00             0.00
#
#       word_freq_mail  word_freq_receive  ...  word_freq_conference  \
# 0               0.00               0.00  ...                   0.0
# 1               0.94               0.21  ...                   0.0
# 2               0.25               0.38  ...                   0.0
# 3               0.63               0.31  ...                   0.0
# 4               0.63               0.31  ...                   0.0
# ...              ...                ...  ...                   ...
# 4596            0.00               0.00  ...                   0.0
# 4597            0.00               0.00  ...                   0.0
# 4598            0.00               0.00  ...                   0.0
# 4599            0.00               0.00  ...                   0.0
# 4600            0.00               0.00  ...                   0.0
#
#       char_freq_;  char_freq_(  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000        0.000        0.778        0.000        0.000
# 1           0.000        0.132        0.372        0.180        0.048
# 2           0.010        0.143        0.276        0.184        0.010
# 3           0.000        0.137        0.137        0.000        0.000
# 4           0.000        0.135        0.135        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 4596        0.000        0.232        0.000        0.000        0.000
# 4597        0.000        0.000        0.353        0.000        0.000
# 4598        0.102        0.718        0.000        0.000        0.000
# 4599        0.000        0.057        0.000        0.000        0.000
# 4600        0.000        0.000        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total  spam
# 0                          278     1
# 1                         1028     1
# 2                         2259     1
# 3                          191     1
# 4                          191     1
# ...                        ...   ...
# 4596                        88     0
# 4597                        14     0
# 4598                       118     0
# 4599                        78     0
# 4600                        40     0
#
# [4601 rows x 56 columns]

# %%
#reset the index values after removing the null values
X = spamData.iloc[:, :-1]
y = spamData.iloc[:, -1].values
print(X.shape)
# Out:
# (4601, 55)

# %%
#Drop duplicate values
spamData = pd.DataFrame(spamData).drop_duplicates()

# %%
spamData.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_our  \
# 0            0.00               0.64           0.64           0.32
# 1            0.21               0.28           0.50           0.14
# 2            0.06               0.00           0.71           1.23
# 3            0.00               0.00           0.00           0.63
# 4            0.00               0.00           0.00           0.63
#
#    word_freq_over  word_freq_remove  word_freq_internet  word_freq_order  \
# 0            0.00              0.00                0.00             0.00
# 1            0.28              0.21                0.07             0.00
# 2            0.19              0.19                0.12             0.64
# 3            0.00              0.31                0.63             0.31
# 4            0.00              0.31                0.63             0.31
#
#    word_freq_mail  word_freq_receive  ...  word_freq_conference  char_freq_;  \
# 0            0.00               0.00  ...                   0.0         0.00
# 1            0.94               0.21  ...                   0.0         0.00
# 2            0.25               0.38  ...                   0.0         0.01
# 3            0.63               0.31  ...                   0.0         0.00
# 4            0.63               0.31  ...                   0.0         0.00
#
#    char_freq_(  char_freq_!  char_freq_$  char_freq_#  \
# 0        0.000        0.778        0.000        0.000
# 1        0.132        0.372        0.180        0.048
# 2        0.143        0.276        0.184        0.010
# 3        0.137        0.137        0.000        0.000
# 4        0.135        0.135        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total  spam
# 0                       278     1
# 1                      1028     1
# 2                      2259     1
# 3                       191     1
# 4                       191     1
#
# [5 rows x 56 columns]

# %%
#Check for spam and no spam count
spamData['spam'].value_counts()
# Out:
# 0    2529
# 1    1679
# Name: spam, dtype: int64

# %%
#Set 0 as no spam and spam as emails as 1 
# spamData.spam[spamData['spam'] == 1] ='spam'
# spamData.spam[spamData['spam'] == 0] ='No spam'

# %%
#Plot the outliers table 
plt.figure(figsize = (14,6))
chart = spamData.boxplot()
chart.set_xticklabels(chart.get_xticklabels(), rotation = 80)
plt.title("Spam message outliers", color ='red')
plt.xlabel('Attributes')
plt.ylabel('Count')
plt.show()

# %%
#Using IQR method setting the outliers as null values
for outlier in ["capital_run_length_average", "capital_run_length_longest", "capital_run_length_total"]:
    quart75, quart25 = np.percentile(spamData.loc[:,outlier], [75,25])
    IQR = quart75 - quart25
    max = quart75 + (1.5 * IQR)
    min = quart25 - (1.5 * IQR)
    spamData.loc[spamData[outlier] < min, outlier] = np.nan
    spamData.loc[spamData[outlier] > max, outlier] = np.nan

# %%
#Drop null values in the dataset
spamData = spamData.dropna()
spamData
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_our  \
# 0               0.00               0.64           0.64           0.32
# 3               0.00               0.00           0.00           0.63
# 4               0.00               0.00           0.00           0.63
# 5               0.00               0.00           0.00           1.85
# 6               0.00               0.00           0.00           1.92
# ...              ...                ...            ...            ...
# 4596            0.31               0.00           0.62           0.00
# 4597            0.00               0.00           0.00           0.00
# 4598            0.30               0.00           0.30           0.00
# 4599            0.96               0.00           0.00           0.32
# 4600            0.00               0.00           0.65           0.00
#
#       word_freq_over  word_freq_remove  word_freq_internet  word_freq_order  \
# 0               0.00              0.00                0.00             0.00
# 3               0.00              0.31                0.63             0.31
# 4               0.00              0.31                0.63             0.31
# 5               0.00              0.00                1.85             0.00
# 6               0.00              0.00                0.00             0.00
# ...              ...               ...                 ...              ...
# 4596            0.31              0.00                0.00             0.00
# 4597            0.00              0.00                0.00             0.00
# 4598            0.00              0.00                0.00             0.00
# 4599            0.00              0.00                0.00             0.00
# 4600            0.00              0.00                0.00             0.00
#
#       word_freq_mail  word_freq_receive  ...  word_freq_conference  \
# 0               0.00               0.00  ...                   0.0
# 3               0.63               0.31  ...                   0.0
# 4               0.63               0.31  ...                   0.0
# 5               0.00               0.00  ...                   0.0
# 6               0.64               0.96  ...                   0.0
# ...              ...                ...  ...                   ...
# 4596            0.00               0.00  ...                   0.0
# 4597            0.00               0.00  ...                   0.0
# 4598            0.00               0.00  ...                   0.0
# 4599            0.00               0.00  ...                   0.0
# 4600            0.00               0.00  ...                   0.0
#
#       char_freq_;  char_freq_(  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000        0.000        0.778        0.000          0.0
# 3           0.000        0.137        0.137        0.000          0.0
# 4           0.000        0.135        0.135        0.000          0.0
# 5           0.000        0.223        0.000        0.000          0.0
# 6           0.000        0.054        0.164        0.054          0.0
# ...           ...          ...          ...          ...          ...
# 4596        0.000        0.232        0.000        0.000          0.0
# 4597        0.000        0.000        0.353        0.000          0.0
# 4598        0.102        0.718        0.000        0.000          0.0
# 4599        0.000        0.057        0.000        0.000          0.0
# 4600        0.000        0.000        0.125        0.000          0.0
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                        61.0
# 3                          3.537                        40.0
# 4                          3.537                        40.0
# 5                          3.000                        15.0
# 6                          1.671                         4.0
# ...                          ...                         ...
# 4596                       1.142                         3.0
# 4597                       1.555                         4.0
# 4598                       1.404                         6.0
# 4599                       1.147                         5.0
# 4600                       1.250                         5.0
#
#       capital_run_length_total  spam
# 0                        278.0     1
# 3                        191.0     1
# 4                        191.0     1
# 5                         54.0     1
# 6                        112.0     1
# ...                        ...   ...
# 4596                      88.0     0
# 4597                      14.0     0
# 4598                     118.0     0
# 4599                      78.0     0
# 4600                      40.0     0
#
# [3444 rows x 56 columns]

# %%
#Applying feature scaling technique
scaler = StandardScaler()
scaledData = scaler.fit_transform(spamData.iloc[:, :-1])

# %%
#Normalize the data
spamScale = pd.DataFrame(data=scaledData, columns=spamData.iloc[:, :-1].columns)
spamScale
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_our  \
# 0          -0.306078           1.152810       0.701464       0.016590
# 1          -0.306078          -0.195432      -0.506042       0.458179
# 2          -0.306078          -0.195432      -0.506042       0.458179
# 3          -0.306078          -0.195432      -0.506042       2.196048
# 4          -0.306078          -0.195432      -0.506042       2.295761
# ...              ...                ...            ...            ...
# 3439        0.694447          -0.195432       0.663729      -0.439244
# 3440       -0.306078          -0.195432      -0.506042      -0.439244
# 3441        0.662172          -0.195432       0.059976      -0.439244
# 3442        2.792323          -0.195432      -0.506042       0.016590
# 3443       -0.306078          -0.195432       0.720331      -0.439244
#
#       word_freq_over  word_freq_remove  word_freq_internet  word_freq_order  \
# 0          -0.303393         -0.263263           -0.228889        -0.214934
# 1          -0.303393          0.607327            1.269771         1.176985
# 2          -0.303393          0.607327            1.269771         1.176985
# 3          -0.303393         -0.263263            4.171938        -0.214934
# 4          -0.303393         -0.263263           -0.228889        -0.214934
# ...              ...               ...                 ...              ...
# 3439        0.798995         -0.263263           -0.228889        -0.214934
# 3440       -0.303393         -0.263263           -0.228889        -0.214934
# 3441       -0.303393         -0.263263           -0.228889        -0.214934
# 3442       -0.303393         -0.263263           -0.228889        -0.214934
# 3443       -0.303393         -0.263263           -0.228889        -0.214934
#
#       word_freq_mail  word_freq_receive  ...  word_freq_table  \
# 0          -0.346124          -0.253274  ...        -0.072973
# 1           0.737934           1.530522  ...        -0.072973
# 2           0.737934           1.530522  ...        -0.072973
# 3          -0.346124          -0.253274  ...        -0.072973
# 4           0.755141           5.270741  ...        -0.072973
# ...              ...                ...  ...              ...
# 3439       -0.346124          -0.253274  ...        -0.072973
# 3440       -0.346124          -0.253274  ...        -0.072973
# 3441       -0.346124          -0.253274  ...        -0.072973
# 3442       -0.346124          -0.253274  ...        -0.072973
# 3443       -0.346124          -0.253274  ...        -0.072973
#
#       word_freq_conference  char_freq_;  char_freq_(  char_freq_!  \
# 0                -0.117434    -0.155392    -0.603680     0.685641
# 1                -0.117434    -0.155392    -0.042572    -0.121616
# 2                -0.117434    -0.155392    -0.050763    -0.124134
# 3                -0.117434    -0.155392     0.309657    -0.294149
# 4                -0.117434    -0.155392    -0.382513    -0.087613
# ...                    ...          ...          ...          ...
# 3439             -0.117434    -0.155392     0.346518    -0.294149
# 3440             -0.117434    -0.155392    -0.603680     0.150408
# 3441             -0.117434     0.319104     2.337017    -0.294149
# 3442             -0.117434    -0.155392    -0.370226    -0.294149
# 3443             -0.117434    -0.155392    -0.603680    -0.136728
#
#       char_freq_$  char_freq_#  capital_run_length_average  \
# 0       -0.266088    -0.073181                    1.197805
# 1       -0.266088    -0.073181                    1.009452
# 2       -0.266088    -0.073181                    1.009452
# 3       -0.266088    -0.073181                    0.547601
# 4        0.011883    -0.073181                   -0.595417
# ...           ...          ...                         ...
# 3439    -0.266088    -0.073181                   -1.050388
# 3440    -0.266088    -0.073181                   -0.695184
# 3441    -0.266088    -0.073181                   -0.825053
# 3442    -0.266088    -0.073181                   -1.046088
# 3443    -0.266088    -0.073181                   -0.957502
#
#       capital_run_length_longest  capital_run_length_total
# 0                       2.264429                  1.205293
# 1                       1.144425                  0.538005
# 2                       1.144425                  0.538005
# 3                      -0.188913                 -0.512782
# 4                      -0.775581                 -0.067923
# ...                          ...                       ...
# 3439                   -0.828915                 -0.252002
# 3440                   -0.775581                 -0.819581
# 3441                   -0.668914                 -0.021903
# 3442                   -0.722248                 -0.328702
# 3443                   -0.722248                 -0.620161
#
# [3444 rows x 55 columns]

# %%
spamScale.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_our  \
# count    3.444000e+03       3.444000e+03   3.444000e+03   3.444000e+03
# mean     1.538258e-15       2.526209e-16   1.486712e-15   5.819709e-15
# std      1.000145e+00       1.000145e+00   1.000145e+00   1.000145e+00
# min     -3.060785e-01      -1.954319e-01  -5.060419e-01  -4.392442e-01
# 25%     -3.060785e-01      -1.954319e-01  -5.060419e-01  -4.392442e-01
# 50%     -3.060785e-01      -1.954319e-01  -5.060419e-01  -4.392442e-01
# 75%     -3.060785e-01      -1.954319e-01   1.731801e-01   7.356929e-02
# max      1.434678e+01       2.988721e+01   9.116270e+00   1.380558e+01
#
#        word_freq_over  word_freq_remove  word_freq_internet  word_freq_order  \
# count    3.444000e+03      3.444000e+03        3.444000e+03     3.444000e+03
# mean     4.904033e-15      5.476552e-15       -3.746052e-15     2.402630e-15
# std      1.000145e+00      1.000145e+00        1.000145e+00     1.000145e+00
# min     -3.033932e-01     -2.632627e-01       -2.288894e-01    -2.149336e-01
# 25%     -3.033932e-01     -2.632627e-01       -2.288894e-01    -2.149336e-01
# 50%     -3.033932e-01     -2.632627e-01       -2.288894e-01    -2.149336e-01
# 75%     -3.033932e-01     -2.632627e-01       -2.288894e-01    -2.149336e-01
# max      2.060642e+01      2.015346e+01        2.619986e+01     2.340278e+01
#
#        word_freq_mail  word_freq_receive  ...  word_freq_table  \
# count    3.444000e+03       3.444000e+03  ...     3.444000e+03
# mean     4.893814e-16       3.971530e-15  ...     5.805541e-16
# std      1.000145e+00       1.000145e+00  ...     1.000145e+00
# min     -3.461239e-01      -2.532743e-01  ...    -7.297345e-02
# 25%     -3.461239e-01      -2.532743e-01  ...    -7.297345e-02
# 50%     -3.461239e-01      -2.532743e-01  ...    -7.297345e-02
# 75%     -3.461239e-01      -2.532743e-01  ...    -7.297345e-02
# max      1.877115e+01       1.476514e+01  ...     2.530467e+01
#
#        word_freq_conference   char_freq_;   char_freq_(   char_freq_!  \
# count          3.444000e+03  3.444000e+03  3.444000e+03  3.444000e+03
# mean          -8.127532e-16  1.988876e-15 -5.680061e-16 -1.503467e-15
# std            1.000145e+00  1.000145e+00  1.000145e+00  1.000145e+00
# min           -1.174344e-01 -1.553924e-01 -6.036796e-01 -2.941492e-01
# 25%           -1.174344e-01 -1.553924e-01 -6.036796e-01 -2.941492e-01
# 50%           -1.174344e-01 -1.553924e-01 -3.333649e-01 -2.941492e-01
# 75%           -1.174344e-01 -1.553924e-01  2.318387e-01  4.636340e-03
# max            3.050372e+01  2.024330e+01  2.100921e+01  4.060767e+01
#
#         char_freq_$   char_freq_#  capital_run_length_average  \
# count  3.444000e+03  3.444000e+03                3.444000e+03
# mean  -3.827658e-15 -1.019139e-15               -3.590495e-16
# std    1.000145e+00  1.000145e+00                1.000145e+00
# min   -2.660883e-01 -7.318139e-02               -1.172517e+00
# 25%   -2.660883e-01 -7.318139e-02               -7.343167e-01
# 50%   -2.660883e-01 -7.318139e-02               -2.647247e-01
# 75%   -2.660883e-01 -7.318139e-02                4.701953e-01
# max    3.063500e+01  4.305673e+01                3.834745e+00
#
#        capital_run_length_longest  capital_run_length_total
# count                3.444000e+03              3.444000e+03
# mean                -2.832938e-16              5.417334e-16
# std                  1.000145e+00              1.000145e+00
# min                 -9.355820e-01             -9.192906e-01
# 25%                 -7.222479e-01             -6.891912e-01
# 50%                 -3.489133e-01             -3.440422e-01
# 75%                  2.510887e-01              2.638036e-01
# max                  4.237769e+00              3.851436e+00
#
# [8 rows x 55 columns]

# %%
#Apllying the PCA technique
pca = PCA()
pcaComp = pca.fit_transform(spamScale)

# %%
#Plot the variance graph
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of components")
plt.ylabel("Varaince as a percentage")
plt.grid(True)
plt.show()

# %%
#Applying PCA for the first 45 atrributes
pca = PCA(n_components=45)
data = pca.fit_transform(spamScale)
PDF = pd.DataFrame(data)
PDF
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.002909  1.801581  0.720301  0.060234 -0.229496 -0.021884 -1.193400
# 1    -0.981264  1.536536  0.302672 -0.019248 -0.300073 -0.164518 -0.693837
# 2    -0.982511  1.536219  0.302084 -0.018471 -0.300258 -0.163976 -0.694451
# 3    -0.586173 -0.154730  0.007288  0.328955 -0.658308 -0.393302  0.167260
# 4    -1.142722  0.746592 -1.666753  0.792670  0.066630  1.535707 -1.329789
# ...        ...       ...       ...       ...       ...       ...       ...
# 3439 -0.538435 -1.336285 -0.499813  0.433783 -0.278996 -0.484276  0.159815
# 3440 -0.930797 -1.006172 -1.234032 -0.262919  1.515879 -0.261191 -0.066180
# 3441 -0.275936 -0.874727 -0.111813  0.050074  0.126311 -0.172827  0.126804
# 3442 -0.710135 -1.140638 -0.792458  0.268457  0.323446 -0.323563 -0.129578
# 3443 -0.874977 -1.240654 -1.260960 -0.301948  1.319045 -0.253880  0.765671
#
#             7         8         9   ...        35        36        37  \
# 0    -0.893058  1.075688  0.857376  ...  0.543665 -0.020861  0.213845
# 1     0.221213 -0.369803 -0.196664  ...  0.134138 -0.837438  0.331048
# 2     0.220345 -0.370229 -0.198282  ...  0.136686 -0.838954  0.332783
# 3     0.773885 -1.263520 -0.046210  ...  0.302809 -0.941317  1.390597
# 4    -0.171241 -0.231543 -0.649398  ... -0.559160  0.085665  0.283598
# ...        ...       ...       ...  ...       ...       ...       ...
# 3439  0.128413  0.281065 -0.856754  ... -0.080482 -0.216192 -0.538882
# 3440  0.803211  0.851632 -0.699078  ...  0.479219  1.032704  0.705123
# 3441 -0.203772  1.221418 -0.936170  ... -0.602675  0.559103 -0.878925
# 3442  0.217626  0.394595 -0.445752  ...  0.790557 -0.145228  0.396841
# 3443  0.196375  0.264761 -0.334604  ... -0.243821 -0.209759 -0.376261
#
#             38        39        40        41            42        43        44
# 0    -0.122592  0.046964 -0.531428 -0.298512 -5.161957e-01 -0.064587 -0.264534
# 1    -0.153501  0.057863  0.334492 -0.523711 -6.022822e-01  0.142793 -0.318594
# 2    -0.151207  0.057339  0.333859 -0.523281 -6.015983e-01  0.143526 -0.319611
# 3     0.406119 -0.698592  0.293293 -0.492845 -8.580428e-01  0.310532 -0.546626
# 4     0.410171  1.163534 -0.401385  0.429762  3.988103e-07  0.661365 -0.129761
# ...        ...       ...       ...       ...           ...       ...       ...
# 3439  0.253374 -0.370425  0.152924  0.349735  7.102274e-02  0.216640  0.069263
# 3440 -0.977444  0.132616  0.156626 -0.042521 -4.512108e-01 -0.079813  0.307979
# 3441 -0.691340 -0.561489  0.163478  0.021461 -6.619355e-01 -0.556026  0.140657
# 3442 -0.442717 -0.204236 -0.242400 -0.135750  1.013148e-02  0.269803  0.294738
# 3443 -0.304747  0.050868  0.619307 -0.253560 -6.508863e-02 -0.175254 -0.173093
#
# [3444 rows x 45 columns]

# %%
#Splitting the dataset as train and test
X_Train, X_Test, y_Train, y_Test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Store the train, test values in arrays
neighbors = np.arange(1,9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# %%
#Building the KNN model
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
    knn.fit(X_Train, y_Train)
    train_accuracy[i] = knn.score(X_Train, y_Train)
    test_accuracy[i] = knn.score(X_Test, y_Test)

# %%
#Build the Decision Tree model
DT = DecisionTreeClassifier(criterion='gini', max_depth=5)

# %%
#Prediction
yPrediction = knn.predict(X_Test)

# %%
#Plot confusionn matrix
matrix = pd.DataFrame((metrics.confusion_matrix(y_Test, yPrediction)), ('Spam (1)', 'Not spam (0)'), ('Spam (1)', 'Not spam (0)'))
print(matrix)
# Out:
#               Spam (1)  Not spam (0)
# Spam (1)           603            88
# Not spam (0)       126           334

# %%
#Plot confusion matrix in a graph
heatmap = sns.heatmap(matrix, annot = True, fmt = 'd', cmap = 'Spectral')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels())
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels())

plt.title('Confusion Matrix', color = 'darkblue')
plt.ylabel('True count')
plt.xlabel('Predicted count')
plt.show()

# %%
# Getting the final acuaracy result of KNN
trainPred = knn.predict(X_Test)
accuracy = metrics.accuracy_score(y_Test, trainPred)
print("***KNN accuracy***: {:.4%}".format(accuracy))
# Out:
# ***KNN accuracy***: 81.4075%

# %%
# hyperparameter to avoid prunning in decision tree
# Using three parameters
parameters = {"max_depth": [2, 4, 6, 8, 10], "min_samples_split": [2, 4, 6, 8, 10], "min_samples_leaf": [1, 2, 3, 4, 5]}

# Usek grid search instance to obtain the best hyperparameters
gridSearch = GridSearchCV(DT, parameters, cv=5)
gridSearch.fit(X_Train, y_Train)

#Accuracy by using hyper paramter tuning
print("Hyperparameter values: ", gridSearch.best_params_)
print("Best accuracy score: ", gridSearch.best_score_)
# Out:
# Hyperparameters:  {'max_depth': 8, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best accuracy value:  0.9202898550724636

# %%
# Getting the final acuaracy result of decison tree
DT.fit(X_Train, y_Train)
accuracy =  DT.score(X_Test, y_Test)
print("***Decision Tree accuarcy***: {:.4%}".format(accuracy))
# Out:
# ***Decision Tree accuarcy***: 89.8349%

# %%
#Classification report
classificationReport = classification_report(y_Test, yPrediction)
print("Classification Report: \n", classificationReport)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       691
#            1       0.79      0.73      0.76       460
#
#     accuracy                           0.81      1151
#    macro avg       0.81      0.80      0.80      1151
# weighted avg       0.81      0.81      0.81      1151
